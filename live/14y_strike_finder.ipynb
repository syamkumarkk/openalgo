# %%
import sys, os
# ROOT_DIR = os.path.abspath(os.path.join(os.path.dirname(__file__), ".."))
# if ROOT_DIR not in sys.path:
#     sys.path.insert(0, ROOT_DIR)
from openalgo import api, ta
from base.MainClass import MainClass
from base.OptionChainDB import OptionChainDB
import pandas as pd
import time,os,sys
from datetime import datetime, timedelta
# ✅ INSTANTIATE THE CLASS
main_obj = MainClass('NIFTY')
db = OptionChainDB("145_NIFTY.db")
# ✅ ACCESS INSTANCE VARIABLES
client = main_obj.client
expiry_dateVal = main_obj.expiry_date
order_utilObj = main_obj.order_util
# ✅ RUN STRATEGY
#main_obj.run()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
posflag = 0
stoploss = 0
entry = 0
flag = 0
exit = 0
target = 0
deltaValue = 0.50
expiry_date = expiry_dateVal.replace("-", "")
expiry_date = main_obj.expiry_date.replace("-", "")
atm = main_obj.get_atm()
now = datetime.now().strftime("%Y-%m-%d")
print(now)
opening_strikes = main_obj.order_util.get_opening_range_strikes(
    expiry_date=expiry_date,
    atm=atm,
    PRICE_LOW=150,
    PRICE_HIGH=170
)
db.save_options_today(opening_strikes)
print("📊 OPENING RANGE STRIKES:", opening_strikes)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       2 # ROOT_DIR = os.path.abspath(os.path.join(os.path.dirname(__file__), ".."))
#       3 # if ROOT_DIR not in sys.path:
#       4 #     sys.path.insert(0, ROOT_DIR)
#       5 from openalgo import api, ta
# ----> 6 from base.MainClass import MainClass
#       7 from base.OptionChainDB import OptionChainDB
#       8 import pandas as pd
#
# ModuleNotFoundError: No module named 'base'

# %%
# ✅ INSTANTIATE THE CLASS
main_obj = MainClass('BANKNIFTY')
db = OptionChainDB("145_BANKNIFTY.db")
# ✅ ACCESS INSTANCE VARIABLES
client = main_obj.client
expiry_dateVal = main_obj.expiry_date
order_utilObj = main_obj.order_util
# ✅ RUN STRATEGY
#main_obj.run()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
posflag = 0
stoploss = 0
entry = 0
flag = 0
exit = 0
target = 0
deltaValue = 0.50
expiry_date = expiry_dateVal.replace("-", "")
expiry_date = main_obj.expiry_date.replace("-", "")
atm = main_obj.get_atm()
now = datetime.now().strftime("%Y-%m-%d")
print(now)
opening_strikes = main_obj.order_util.get_opening_range_strikes(
    expiry_date=expiry_date,
    atm=atm,
    PRICE_LOW=350,
    PRICE_HIGH=400
)
db.save_options_today(opening_strikes)
print("📊 OPENING RANGE STRIKES:", opening_strikes)

# %%
import sys, os,time,json
from datetime import datetime, timedelta
try:
    BASE_DIR = os.path.dirname(__file__)
except NameError:
    BASE_DIR = os.getcwd()

ROOT_DIR = os.path.abspath(os.path.join(BASE_DIR, ".."))
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
    from base.MainClass import MainClass
main_obj = MainClass('BANKNIFTY')
# order = main_obj.client.placeorder(
#                         strategy=f"TEST_BUY",
#                         symbol='BANKNIFTY27JAN2659900PE',
#                         exchange="NFO",
#                         action="BUY",
#                         pricetype="MARKET",
#                         product="NRML",
#                         quantity=30 
#                     )
# print(order)
# print(type(order))   # <-- this is str 26012013348143
order = {"mode": "analyze", "orderid": "26012028377816", "status": "success"}
order_id = order.get("orderid")
# print('order_id')
# print(order_id)
# order_id = order["orderid"]
# print(order_id)
time.sleep(1)  # allow exchange to update orderbook

orders = main_obj.client.orderbook()
placed_time = None
for o in orders["data"]["orders"]:
    if o.get("orderid") == order_id:
        placed_time = datetime.strptime(o.get("timestamp"), "%Y-%m-%d %H:%M:%S")
        break

if not placed_time:
    raise Exception("❌ Unable to find order placed time")
print("📅 ORDER PLACED TIME:", placed_time)

# ==============================
# STEP 3: WAIT FOR 5-MIN CANDLE CLOSE
# ==============================
sl_place_time = main_obj.next_5min_close(placed_time)
print("⏳ Waiting till candle close:", sl_place_time)
print("⏳ datetime.now():", datetime.now())
while datetime.now() < sl_place_time:
    time.sleep(1)
if datetime.now() > sl_place_time:
    print("✅ Candle closed, calculating SL and place order")

# # ==============================
# # STEP 4: GET COMPLETED CANDLE
# # ==============================
# completed_candle = main_obj.get_last_completed_5min_candle()

# if completed_candle is None:
#     raise Exception("❌ No completed candle data")

# sl_price = round(completed_candle["low"], 2)
# print("🛑 SL based on candle low:", sl_price)
# Out:
# 📅 Using Expiry: 27-JAN-26
# 📅 ORDER PLACED TIME: 2026-01-20 17:01:49
# ⏳ Waiting till candle close: 2026-01-20 17:05:00
# ⏳ datetime.now(): 2026-01-20 18:13:25.455313
# ✅ Candle closed, calculating SL and place order

# %%
import sys, os,time,json
from datetime import datetime, timedelta
try:
    BASE_DIR = os.path.dirname(__file__)
except NameError:
    BASE_DIR = os.getcwd()

ROOT_DIR = os.path.abspath(os.path.join(BASE_DIR, ".."))
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
    from base.MainClass import MainClass
main_obj = MainClass('BANKNIFTY')
ENTRY_TRIGGER = 420
ENTRY_TRIGGER_BTW = (ENTRY_TRIGGER+5)
SL_POINTS = 50
TARGET_POINTS = 60
symbol = 'BANKNIFTY27JAN2659500PE'
ltp = main_obj.safe_ltp(symbol)
entry_price = ltp
sl_price = entry_price - SL_POINTS
target_price = entry_price + TARGET_POINTS
print(f"✅ BOUGHT @ {entry_price}")
print(f"🛑 SL: {sl_price} | 🎯 TARGET: {target_price}")
test_order = '26012164226651'

orders = main_obj.client.orderbook()
print(orders)
my_order = None
for o in orders["data"]["orders"]:
    if o.get("orderid") == test_order:
        print("order found")
        my_order= o
        # placed_time = datetime.strptime(o.get("timestamp"), "%Y-%m-%d %H:%M:%S")
        break
    

print(my_order)
order_id = my_order.get("orderid")
print(order_id)
print(my_order.get("timestamp"))
time.sleep(1)  # allow exchange to update orderbook
# placed_time = None                        
placed_time = datetime.strptime(my_order.get("timestamp"), "%Y-%m-%d %H:%M:%S")
if not placed_time:
    raise Exception("❌ Unable to find order placed time")
print("📅 ORDER PLACED TIME:", placed_time)
# ==============================
# STEP 1: WAIT FOR 5-MIN CANDLE CLOSE
# ==============================
sl_place_time = main_obj.next_5min_close(placed_time)
print("⏳ Waiting till candle close:", sl_place_time)
print("⏳ datetime.now():", datetime.now())
while datetime.now() < sl_place_time:
    time.sleep(1)
if datetime.now() > sl_place_time:
    print("✅ Candle closed, calculating SL and place order")
    #main_obj.bracket_targe_sell(symbol,sl_price,target_price,"MIS","145PE",order_id)
    print("📌 SL & TARGET PLACED")
else:
    print("📌 SL & TARGET NOT PLACED")
# Out:
# 📅 Using Expiry: 27-JAN-26
# ✅ BOUGHT @ 437.3
# 🛑 SL: 387.3 | 🎯 TARGET: 497.3
# {'data': {'orders': [{'action': 'BUY', 'average_price': 428.0, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012193563173', 'pending_quantity': 0, 'price': 427.05, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:38:49', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 429.45, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012173103807', 'pending_quantity': 0, 'price': 429.05, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:38:44', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 421.35, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012165950380', 'pending_quantity': 0, 'price': 421.6, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:38:39', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 424.1, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012152943943', 'pending_quantity': 0, 'price': 421.25, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:37:54', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 422.6, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012164226651', 'pending_quantity': 0, 'price': 421.85, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:37:50', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 184.25, 'exchange': 'NFO', 'filled_quantity': 65, 'order_status': 'complete', 'orderid': '26012140942706', 'pending_quantity': 0, 'price': 183.15, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 65, 'rejection_reason': '', 'strategy': '145CE_NIFTY_BUY', 'symbol': 'NIFTY27JAN2625250CE', 'timestamp': '2026-01-21 09:35:31', 'trigger_price': 0.0}], 'statistics': {'total_buy_orders': 6, 'total_completed_orders': 6, 'total_open_orders': 0, 'total_rejected_orders': 0, 'total_sell_orders': 0}}, 'mode': 'analyze', 'status': 'success'}
# order found
# {'action': 'BUY', 'average_price': 422.6, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012164226651', 'pending_quantity': 0, 'price': 421.85, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:37:50', 'trigger_price': 0.0}
# 26012164226651
# 2026-01-21 09:37:50
# 📅 ORDER PLACED TIME: 2026-01-21 09:37:50
# ⏳ Waiting till candle close: 2026-01-21 09:40:00
# ⏳ datetime.now(): 2026-01-21 09:49:46.598148
# ✅ Candle closed, calculating SL and place order
# 📌 SL & TARGET PLACED

# %%
orders = main_obj.client.orderbook()
order_list = orders.get("data", [])
if not order_list:
    print("ℹ️ No orders found")

#print(order_list)
# ------------------------------------------
# Filter running orders
# ------------------------------------------
order_list_orders = order_list["orders"]
complete_orders_status = [ 
                            o for o in order_list_orders if o.get("order_status") == "complete" and o.get("strategy", "").startswith(f"145")
                        ]
print(complete_orders_status)
for k in complete_orders_status:
    symbol = k.get("symbol") 
    strategy_name='145'
    if symbol.endswith("PE"):
        strategy_name = strategy_name+"PE_"
        strategy_prefix= strategy_name+"PE"
    elif symbol.endswith("CE"):
        strategy_name = strategy_name+"CE_"
        strategy_prefix= strategy_name+"CE"
    
    if symbol.startswith("BANKNIFTY"):
        strategy_name = strategy_name+"BANKNIFTY_"
    elif symbol.startswith("NIFTY"):
        strategy_name = strategy_name+"NIFTY_"
    
    strategy_name= strategy_name+k.get("orderid")+"_"
    print(strategy_name)
    complete_open_orders_status = [ 
                            j for j in order_list_orders if j.get("order_status") == "open" and j.get("strategy", "").startswith(strategy_name)
                        ]
    print(len(complete_open_orders_status))
    if(len(complete_open_orders_status)==0):
        placed_order_id=k.get("orderid")
        time.sleep(1)  # allow exchange to update orderbook
        # placed_time = None                        
        placed_time = datetime.strptime(k.get("timestamp"), "%Y-%m-%d %H:%M:%S")
        if not placed_time:
            raise Exception("❌ Unable to find order placed time")
        print("📅 ORDER PLACED TIME:", placed_time)
        # ==============================
        # STEP 1: WAIT FOR 5-MIN CANDLE CLOSE
        # ==============================
        sl_place_time = main_obj.parent.next_5min_close(placed_time)
        print("⏳ Waiting till candle close:", sl_place_time)
        print("⏳ datetime.now():", datetime.now())
        while datetime.now() < sl_place_time:
            time.sleep(1)
        if datetime.now() > sl_place_time:
            print("✅ Candle closed, calculating SL and place order")
            main_obj.bracket_targe_sell(symbol,sl_price,target_price,"MIS",strategy_prefix,placed_order_id)
            print("📌 SL & TARGET PLACED")
        else:
            print("📌 SL & TARGET NOT PLACED")

    break
# Out:
# [{'action': 'BUY', 'average_price': 186.55, 'exchange': 'NFO', 'filled_quantity': 65, 'order_status': 'complete', 'orderid': '26012161901209', 'pending_quantity': 0, 'price': 186.6, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 65, 'rejection_reason': '', 'strategy': '145PE_NIFTY_BUY', 'symbol': 'NIFTY27JAN2625300PE', 'timestamp': '2026-01-21 09:54:35', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 186.25, 'exchange': 'NFO', 'filled_quantity': 65, 'order_status': 'complete', 'orderid': '26012123845718', 'pending_quantity': 0, 'price': 186.25, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 65, 'rejection_reason': '', 'strategy': '145PE_NIFTY_BUY', 'symbol': 'NIFTY27JAN2625300PE', 'timestamp': '2026-01-21 09:54:32', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 187.05, 'exchange': 'NFO', 'filled_quantity': 65, 'order_status': 'complete', 'orderid': '26012106824498', 'pending_quantity': 0, 'price': 186.85, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 65, 'rejection_reason': '', 'strategy': '145PE_NIFTY_BUY', 'symbol': 'NIFTY27JAN2625300PE', 'timestamp': '2026-01-21 09:54:29', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 186.35, 'exchange': 'NFO', 'filled_quantity': 65, 'order_status': 'complete', 'orderid': '26012181284270', 'pending_quantity': 0, 'price': 186.45, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 65, 'rejection_reason': '', 'strategy': '145PE_NIFTY_BUY', 'symbol': 'NIFTY27JAN2625300PE', 'timestamp': '2026-01-21 09:54:25', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 185.9, 'exchange': 'NFO', 'filled_quantity': 65, 'order_status': 'complete', 'orderid': '26012122594491', 'pending_quantity': 0, 'price': 186.55, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 65, 'rejection_reason': '', 'strategy': '145PE_NIFTY_BUY', 'symbol': 'NIFTY27JAN2625300PE', 'timestamp': '2026-01-21 09:54:23', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 428.0, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012193563173', 'pending_quantity': 0, 'price': 427.05, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:38:49', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 429.45, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012173103807', 'pending_quantity': 0, 'price': 429.05, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:38:44', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 421.35, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012165950380', 'pending_quantity': 0, 'price': 421.6, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:38:39', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 424.1, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012152943943', 'pending_quantity': 0, 'price': 421.25, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:37:54', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 422.6, 'exchange': 'NFO', 'filled_quantity': 30, 'order_status': 'complete', 'orderid': '26012164226651', 'pending_quantity': 0, 'price': 421.85, 'pricetype': 'MARKET', 'product': 'MIS', 'quantity': 30, 'rejection_reason': '', 'strategy': '145PE_BANKNIFTY_BUY', 'symbol': 'BANKNIFTY27JAN2659500PE', 'timestamp': '2026-01-21 09:37:50', 'trigger_price': 0.0}, {'action': 'BUY', 'average_price': 184.25, 'exchange': 'NFO', 'filled_quantity': 65, 'order_status': 'com ...
# 145PE_NIFTY_26012161901209_
# 0
